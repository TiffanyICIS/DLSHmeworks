# %% [markdown]
# <p style="align: center;"><img align=center src="https://s8.hostingkartinok.com/uploads/images/2018/08/308b49fcfbc619d629fe4604bceb67ac.jpg" width=500 height=450/></p>
#
# <h3 style="text-align: center;"><b>Школа глубокого обучения ФПМИ МФТИ</b></h3>
#
# <h3 style="text-align: center;"><b>Домашнее задание. Полносвязные и свёрточные нейронные сети</b></h3>
#
# В этом занятии вам предстоит потренироваться построению нейронных сетей с помощью библиотеки Pytorch. Делать мы это будем на нескольких датасетах.

# %%
# !pip install torch
# Out:
# Collecting torch
#   Downloading torch-1.13.0-cp39-cp39-manylinux1_x86_64.whl (890.2 MB)
#      |████████████████████████████████| 890.2 MB 31 kB/s  eta 0:00:019     |███████▉                        | 216.5 MB 11.4 MB/s eta 0:01:00
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      |████████████████████████████████| 849 kB 11.6 MB/s eta 0:00:01
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      |████████████████████████████████| 21.0 MB 443 kB/s  eta 0:00:01
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      |████████████████████████████████| 317.1 MB 71 kB/s  eta 0:00:019
# Requirement already satisfied: typing-extensions in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from torch) (4.1.1)
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      |████████████████████████████████| 557.1 MB 29 kB/s s eta 0:00:01
# Requirement already satisfied: setuptools in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (61.2.0)
# Requirement already satisfied: wheel in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.37.1)
# Installing collected packages: nvidia-cublas-cu11, nvidia-cudnn-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, torch
# Successfully installed nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 torch-1.13.0

# %%
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

import torch
from torch import nn
from torch.nn import functional as F

from torch.utils.data import TensorDataset, DataLoader

sns.set(style="darkgrid", font_scale=1.4)

# %% [markdown]
# # Часть 1. Датасет moons
#
# Давайте сгенерируем датасет и посмотрим на него!

# %%
X, y = make_moons(n_samples=10000, random_state=42, noise=0.1)

# %%
X.shape, y.shape
# Out:
# ((10000, 2), (10000,))

# %%
X
# Out:
# array([[ 0.45549318, -0.12550304],
#        [-0.70421731,  0.04130827],
#        [ 0.41379864,  0.79132194],
#        ...,
#        [-0.03803096,  0.24540791],
#        [ 0.8698024 ,  0.52329471],
#        [ 1.16429638, -0.3798397 ]])

# %%
plt.figure(figsize=(16, 10))
plt.title("Dataset")
plt.scatter(X[:, 0], X[:, 1], c=y, cmap="viridis")
plt.show()

# %% [markdown]
# Сделаем train/test split

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=42)

# %% [markdown]
# ### Загрузка данных
# В PyTorch загрузка данных как правило происходит налету (иногда датасеты не помещаются в оперативную память). Для этого используются две сущности `Dataset` и `DataLoader`.
#
# 1.   `Dataset` загружает каждый объект по отдельности.
#
# 2.   `DataLoader` группирует объекты из `Dataset` в батчи.
#
# Так как наш датасет достаточно маленький мы будем использовать `TensorDataset`. Все, что нам нужно, это перевести из массива numpy в тензор с типом `torch.float32`.
#
# ### Задание. Создайте тензоры с обучающими и тестовыми данными

# %%
X_train_t =  torch.from_numpy(X_train).type(torch.FloatTensor)
y_train_t =  torch.from_numpy(y_train).type(torch.FloatTensor)
X_val_t =  torch.from_numpy(X_val).type(torch.FloatTensor)
y_val_t =  torch.from_numpy(y_val).type(torch.FloatTensor)

# %%
X_train_t
# Out:
# tensor([[ 0.5020, -0.3376],
#         [-0.0200,  0.2391],
#         [ 0.5703,  0.8117],
#         ...,
#         [ 0.3216, -0.3567],
#         [ 2.0134,  0.0323],
#         [ 0.1791,  0.9310]])

# %% [markdown]
# Создаем `Dataset` и `DataLoader`.

# %%
train_dataset = TensorDataset(X_train_t, y_train_t)
val_dataset = TensorDataset(X_val_t, y_val_t)
train_dataloader = DataLoader(train_dataset, batch_size=128)
val_dataloader = DataLoader(val_dataset, batch_size=128)

# %% [markdown]
# ## Logistic regression is my profession
#
# **Напоминание**
# Давайте вспоним, что происходит в логистической регрессии. На входе у нас есть матрица объект-признак X и столбец-вектор $y$ – метки из $\{0, 1\}$ для каждого объекта. Мы хотим найти такую матрицу весов $W$ и смещение $b$ (bias), что наша модель $XW + b$ будет каким-то образом предсказывать класс объекта. Как видно на выходе наша модель может выдавать число в интервале от $(-\infty;\infty)$. Этот выход как правило называют "логитами" (logits). Нам необходимо перевести его на интервал от $[0;1]$ для того, чтобы он выдавал нам вероятность принадлежности объекта к кассу один, также лучше, чтобы эта функция была монотонной, быстро считалась, имела производную и на $-\infty$ имела значение $0$, а на $+\infty$ имела значение $1$. Такой класс функций называется сигмоидыю. Чаще всего в качестве сигмоида берут
# $$
# \sigma(x) = \frac{1}{1 + e^{-x}}.
# $$

# %% [markdown]
# ### Задание. Реализация логистической регрессии
#
# Вам необходимо написать модуль на PyTorch реализующий $logits = XW + b$, где $W$ и $b$ – параметры (`nn.Parameter`) модели. Иначе говоря, здесь мы реализуем своими руками модуль `nn.Linear` (в этом пункте его использование запрещено). Инициализируйте веса нормальным распределением (`torch.randn`).

# %%
class LinearRegression(nn.Module):
    def __init__(self, in_features: int, out_features: int, bias: bool = True):
        super().__init__()
        self.weights = nn.Parameter(torch.randn(in_features, out_features, requires_grad = True))
        self.bias = bias
        if bias:
            self.bias_term = nn.Parameter(torch.randn(1, requires_grad = True))

    def forward(self, x):
        x = x @ self.weights
        if self.bias:
            x += self.bias_term
        return x

# %%
linear_regression = LinearRegression(2, 1)
loss_function = nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(linear_regression.parameters(), lr=0.05)

# %% [markdown]
# **Вопрос 1.** Сколько обучаемых параметров у получившейся модели? Имеется в виду суммарное количество отдельных числовых переменных, а не количество тензоров.

# %% [markdown]
# Ответ: 3

# %% [markdown]
# ### Train loop
#
# Вот псевдокод, который поможет вам разобраться в том, что происходит во время обучения
#
# ```python
# for epoch in range(max_epochs):  # <----------- итерируемся по датасету несколько раз
#     for x_batch, y_batch in dataset:  # <------ итерируемся по датасету. Так как мы используем SGD а не GD, то берем батчи заданного размера
#         optimizer.zero_grad()  # <------------- обуляем градиенты модели
#         outp = model(x_batch)  # <------------- получаем "логиты" из модели
#         loss = loss_func(outp, y_batch)  # <--- считаем "лосс" для логистической регрессии
#         loss.backward()  # <------------------- считаем градиенты
#         optimizer.step()  # <------------------ делаем шаг градиентного спуска
#         if convergence:  # <------------------- в случае сходимости выходим из цикла
#             break
# ```
#
# В коде ниже добавлено логирование `accuracy` и `loss`.

# %% [markdown]
# ### Задание. Реализация цикла обучения

# %%
sigm = nn.Sigmoid()

# %%
tol = 1e-3
losses = []
max_epochs = 100
prev_weights = torch.zeros_like(linear_regression.weights)
stop_it = False
for epoch in range(max_epochs):
    for it, (X_batch, y_batch) in enumerate(train_dataloader):
        optimizer.zero_grad()
        outp = linear_regression(X_batch)
        loss = loss_function(outp, y_batch[:, None])
        loss.backward()
        losses.append(loss.detach().flatten()[0])
        optimizer.step()
        probabilities = sigm(outp)
        preds = (probabilities > 0.5).type(torch.long)
        batch_acc = (preds.flatten() == y_batch).type(torch.float32).sum() / y_batch.size(0)
        
        if (it + epoch * len(train_dataloader)) % 100 == 0:
            print(f"Iteration: {it + epoch * len(train_dataloader)}\nBatch accuracy: {batch_acc}")
        current_weights = linear_regression.weights.detach().clone()
        if (prev_weights - current_weights).abs().max() < tol:
            print(f"\nIteration: {it + epoch * len(train_dataloader)}.Convergence. Stopping iterations.")
            stop_it = True
            break
        prev_weights = current_weights
    if stop_it:
        break
# Out:
# Iteration: 0
# Batch accuracy: 0.21875
# Iteration: 100
# Batch accuracy: 0.828125
# Iteration: 200
# Batch accuracy: 0.828125
# Iteration: 300
# Batch accuracy: 0.90625
# Iteration: 400
# Batch accuracy: 0.890625
# Iteration: 500
# Batch accuracy: 0.8984375
# Iteration: 600
# Batch accuracy: 0.859375
# Iteration: 700
# Batch accuracy: 0.828125
# Iteration: 800
# Batch accuracy: 0.84375
#
# Iteration: 814.Convergence. Stopping iterations.

# %% [markdown]
# **Вопрос 2.** Сколько итераций потребовалось, чтобы алгоритм сошелся?
#
# **Ответ:** 814

# %% [markdown]
# ### Визуализируем результаты

# %%
plt.figure(figsize=(12, 8))
plt.plot(range(len(losses)), losses)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.show()

# %%
import numpy as np

sns.set(style="white")

xx, yy = np.mgrid[-1.5:2.5:.01, -1.:1.5:.01]
grid = np.c_[xx.ravel(), yy.ravel()]
batch = torch.from_numpy(grid).type(torch.float32)
with torch.no_grad():
    probs = torch.sigmoid(linear_regression(batch).reshape(xx.shape))
    probs = probs.numpy().reshape(xx.shape)

f, ax = plt.subplots(figsize=(16, 10))
ax.set_title("Decision boundary", fontsize=14)
contour = ax.contourf(xx, yy, probs, 25, cmap="RdBu",
                      vmin=0, vmax=1)
ax_c = f.colorbar(contour)
ax_c.set_label("$P(y = 1)$")
ax_c.set_ticks([0, .25, .5, .75, 1])

ax.scatter(X[100:,0], X[100:, 1], c=y[100:], s=50,
           cmap="RdBu", vmin=-.2, vmax=1.2,
           edgecolor="white", linewidth=1)

ax.set(xlabel="$X_1$", ylabel="$X_2$")
plt.show()

# %% [markdown]
# ### Задание. Реализуйте predict и посчитайте accuracy на test.

# %%
@torch.no_grad()
def predict(dataloader, model):
    model.eval()
    predictions = np.array([])
    for x_batch, _ in dataloader:
        outs = linear_regression(x_batch)
        preds = torch.round(sigm(outs))
        predictions = np.hstack((predictions, preds.numpy().flatten()))
    return (predictions.flatten() > 0.5).astype(int)

# %%
from sklearn.metrics import accuracy_score
y_pred = predict(val_dataloader, linear_regression)
print(f"Accuracy = {accuracy_score(y_val_t, y_pred)}")
# Out:
# Accuracy = 0.8664

# %% [markdown]
# **Вопрос 3**
#
# Какое `accuracy` получается после обучения?
#
# **Ответ:** 0.8664

# %% [markdown]
# # Часть 2. Датасет MNIST
# Датасет MNIST содержит рукописные цифры. Загрузим датасет и создадим DataLoader-ы. Пример можно найти в семинаре по полносвязным нейронным сетям.

# %%
# !pip install torchvision
# Out:
# Collecting torchvision
#   Downloading torchvision-0.14.0-cp39-cp39-manylinux1_x86_64.whl (24.3 MB)
#      |████████████████████████████████| 24.3 MB 11.9 MB/s eta 0:00:01
# Requirement already satisfied: torch==1.13.0 in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from torchvision) (1.13.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from torchvision) (9.0.1)
# Requirement already satisfied: numpy in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from torchvision) (1.21.5)
# Requirement already satisfied: requests in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from torchvision) (2.27.1)
# Requirement already satisfied: typing-extensions in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from torchvision) (4.1.1)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from torch==1.13.0->torchvision) (11.7.99)
# Requirement already satisfied: wheel in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->torchvision) (0.37.1)
# Requirement already satisfied: setuptools in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->torchvision) (61.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (3.3)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.14.0

# %%
from torchvision import transforms as tfs

# %%
import os
from torchvision.datasets import MNIST

data_tfs = tfs.Compose([
    tfs.ToTensor(),
    tfs.Normalize((0.5), (0.5))
])

# install for train and test
root = './'
train_dataset = MNIST(root, train=True,  transform=data_tfs, download=True)
val_dataset  = MNIST(root, train=False, transform=data_tfs, download=True)

train_dataloader =  DataLoader(train_dataset, batch_size = 128)
valid_dataloader =  DataLoader(val_dataset, batch_size = 128)

# %% [markdown]
# ## Часть 2.1. Полносвязные нейронные сети
# Сначала решим MNIST с помощью полносвязной нейронной сети.

# %%
class Identical(nn.Module):
    def forward(self, x):
        return x

# %% [markdown]
# ### Задание. Простая полносвязная нейронная сеть
#
# Создайте полносвязную нейронную сеть с помощью класса Sequential. Сеть состоит из:
# * Уплощения матрицы в вектор (nn.Flatten);
# * Двух скрытых слоёв из 128 нейронов с активацией nn.ELU;
# * Выходного слоя с 10 нейронами.
#
# Задайте лосс для обучения (кросс-энтропия).

# %%
model = nn.Sequential(
    nn.Flatten(),
    nn.Linear(784, 128),
    nn.ELU(),
    nn.Linear(128, 128),
    nn.ELU(),
    nn.Linear(128, 10),
)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

loaders = {"train": train_dataloader, "valid": valid_dataloader}

# %% [markdown]
# ### Train loop (seriously)
#
# Давайте разберемся с кодом ниже, который подойдет для 90% задач в будущем.
#
#
# ```python
# for epoch in range(max_epochs):  # <--------------- итерируемся по датасету несколько раз
#     for k, dataloader in loaders.items():  # <----- несколько dataloader для train / valid / test
#         for x_batch, y_batch in dataloader:  # <--- итерируемся по датасету. Так как мы используем SGD а не GD, то берем батчи заданного размера
#             if k == "train":
#                 model.train()  # <------------------ переводим модель в режим train
#                 optimizer.zero_grad()  # <--------- обнуляем градиенты модели
#                 outp = model(x_batch)
#                 loss = criterion(outp, y_batch) # <-считаем "лосс" для логистической регрессии
#                 loss.backward()  # <--------------- считаем градиенты
#                 optimizer.step()  # <-------------- делаем шаг градиентного спуска
#             else:  # <----------------------------- test/eval
#                 model.eval()  # <------------------ переводим модель в режим eval
#                 with torch.no_grad():  # <--------- НЕ считаем градиенты
#                     outp = model(x_batch)  # <------------- получаем "логиты" из модели
#             count_metrics(outp, y_batch)  # <-------------- считаем метрики
# ```

# %% [markdown]
# ### Задание. Дополните цикл обучения.

# %%
history = []
max_epochs = 10
accuracy = {"train": [], "valid": []}
for epoch in range(max_epochs):
    for k, dataloader in loaders.items():
        epoch_correct = 0
        epoch_all = 0
        for x_batch, y_batch in dataloader:
            if k == "train":
                model.train()
                optimizer.zero_grad()
                outp = model(x_batch)
                loss = criterion(outp, y_batch)
                history.append(loss.item())               
                loss.backward()
                optimizer.step()
            else:
                model.eval()
                with torch.no_grad():
                    outp = model(x_batch)
            preds = outp.argmax(-1)
            correct = (preds == y_batch).numpy().sum()
            all =  preds.shape[0]
            epoch_correct += correct.item()
            epoch_all += all
        if k == "train":
            print(f"Epoch: {epoch+1}")
        print(f"Loader: {k}. Accuracy: {epoch_correct/epoch_all}")
        accuracy[k].append(epoch_correct/epoch_all)
# Out:
# Epoch: 1
# Loader: train. Accuracy: 0.88095
# Loader: valid. Accuracy: 0.92
# Epoch: 2
# Loader: train. Accuracy: 0.94225
# Loader: valid. Accuracy: 0.9437
# Epoch: 3
# Loader: train. Accuracy: 0.9591833333333334
# Loader: valid. Accuracy: 0.9512
# Epoch: 4
# Loader: train. Accuracy: 0.9682
# Loader: valid. Accuracy: 0.9548
# Epoch: 5
# Loader: train. Accuracy: 0.9737166666666667
# Loader: valid. Accuracy: 0.9622
# Epoch: 6
# Loader: train. Accuracy: 0.97735
# Loader: valid. Accuracy: 0.9617
# Epoch: 7
# Loader: train. Accuracy: 0.98065
# Loader: valid. Accuracy: 0.9597
# Epoch: 8
# Loader: train. Accuracy: 0.98415
# Loader: valid. Accuracy: 0.9648
# Epoch: 9
# Loader: train. Accuracy: 0.9857166666666667
# Loader: valid. Accuracy: 0.9667
# Epoch: 10
# Loader: train. Accuracy: 0.9871833333333333
# Loader: valid. Accuracy: 0.968

# %% [markdown]
# ### Задание. Протестируйте разные функции активации.
# Попробуйте разные функции активации. Для каждой функции активации посчитайте массив validation accuracy. Лучше реализовать это в виде функции, берущей на вход активацию и получающей массив из accuracies.

# %%
elu_accuracy = accuracy["valid"]

# %%
elu_accuracy
# Out:
# [0.92, 0.9437, 0.9512, 0.9548, 0.9622, 0.9617, 0.9597, 0.9648, 0.9667, 0.968]

# %%
# !pip install torchsummary
# Out:
# Collecting torchsummary
#   Downloading torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Installing collected packages: torchsummary
# Successfully installed torchsummary-1.5.1

# %%
from torchsummary import summary

# %%
# YOUR CODE. Do the same thing with other activations (it's better to wrap into a function that returns a list of accuracies)

def test_activation_function(activation):
    print(f"Activation function is {activation}")
    # Создание модели
    modules = [nn.Flatten(), nn.Linear(784, 128)]
    if activation != Identical:
        modules.append(activation)
    modules.append(nn.Linear(128, 128))
    if activation != Identical:
        modules.append(activation)
    modules.append(nn.Linear(128, 10))
    model = nn.Sequential(*modules)
    summary(model, (784,), batch_size=128)
    #Обучение модели
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters())
    max_epochs = 10
    accuracy = {"train": [], "valid": []}
    for epoch in range(max_epochs):
        for k, dataloader in loaders.items():
            epoch_correct = 0
            epoch_all = 0
            for x_batch, y_batch in dataloader:
                if k == "train":
                    model.train()
                    optimizer.zero_grad()
                    outp = model(x_batch)
                    loss = criterion(outp, y_batch)            
                    loss.backward()
                    optimizer.step()
                else:
                    model.eval()
                    with torch.no_grad():
                        outp = model(x_batch)
                preds = outp.argmax(-1)
                correct = (preds == y_batch).numpy().sum()
                all =  preds.shape[0]
                epoch_correct += correct.item()
                epoch_all += all
            if k == "train":
                print(f"Epoch: {epoch+1}")
            print(f"Loader: {k}. Accuracy: {epoch_correct/epoch_all}")
            accuracy[k].append(epoch_correct/epoch_all)
    return accuracy["valid"]

# %%
plain_accuracy = test_activation_function(Identical)
relu_accuracy = test_activation_function(nn.ReLU())
leaky_relu_accuracy = test_activation_function(nn.LeakyReLU())
# Out:
# Activation function is <class '__main__.Identical'>
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                 [128, 784]               0
#             Linear-2                 [128, 128]         100,480
#             Linear-3                 [128, 128]          16,512
#             Linear-4                  [128, 10]           1,290
# ================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.38
# Forward/backward pass size (MB): 1.03
# Params size (MB): 0.45
# Estimated Total Size (MB): 1.86
# ----------------------------------------------------------------
# Epoch: 1
# Loader: train. Accuracy: 0.8642333333333333
# Loader: valid. Accuracy: 0.8796
# Epoch: 2
# Loader: train. Accuracy: 0.8956666666666667
# Loader: valid. Accuracy: 0.9009
# Epoch: 3
# Loader: train. Accuracy: 0.8997666666666667
# Loader: valid. Accuracy: 0.902
# Epoch: 4
# Loader: train. Accuracy: 0.9023166666666667
# Loader: valid. Accuracy: 0.9018
# Epoch: 5
# Loader: train. Accuracy: 0.9041
# Loader: valid. Accuracy: 0.9015
# Epoch: 6
# Loader: train. Accuracy: 0.9055
# Loader: valid. Accuracy: 0.9017
# Epoch: 7
# Loader: train. Accuracy: 0.9068166666666667
# Loader: valid. Accuracy: 0.9023
# Epoch: 8
# Loader: train. Accuracy: 0.9078833333333334
# Loader: valid. Accuracy: 0.9031
# Epoch: 9
# Loader: train. Accuracy: 0.9093333333333333
# Loader: valid. Accuracy: 0.9045
# Epoch: 10
# Loader: train. Accuracy: 0.9101666666666667
# Loader: valid. Accuracy: 0.905
# Activation function is ReLU()
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                 [128, 784]               0
#             Linear-2                 [128, 128]         100,480
#               ReLU-3                 [128, 128]               0
#             Linear-4                 [128, 128]          16,512
#               ReLU-5                 [128, 128]               0
#             Linear-6                  [128, 10]           1,290
# ================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.38
# Forward/backward pass size (MB): 1.28
# Params size (MB): 0.45
# Estimated Total Size (MB): 2.11
# ----------------------------------------------------------------
# Epoch: 1
# Loader: train. Accuracy: 0.8667833333333334
# Loader: valid. Accuracy: 0.9251
# Epoch: 2
# Loader: train. Accuracy: 0.9324166666666667
# Loader: valid. Accuracy: 0.9408
# Epoch: 3
# Loader: train. Accuracy: 0.9498166666666666
# Loader: valid. Accuracy: 0.9491
# Epoch: 4
# Loader: train. Accuracy: 0.96075
# Loader: valid. Accuracy: 0.9561
# Epoch: 5
# Loader: train. Accuracy: 0.9676666666666667
# Loader: valid. Accuracy: 0.962
# Epoch: 6
# Loader: train. Accuracy: 0.9720833333333333
# Loader: valid. Accuracy: 0.9617
# Epoch: 7
# Loader: train. Accuracy: 0.9764
# Loader: valid. Accuracy: 0.9661
# Epoch: 8
# Loader: train. Accuracy: 0.9792333333333333
# Loader: valid. Accuracy: 0.9702
# Epoch: 9
# Loader: train. Accuracy: 0.9815166666666667
# Loader: valid. Accuracy: 0.9699
# Epoch: 10
# Loader: train. Accuracy: 0.9832833333333333
# Loader: valid. Accuracy: 0.9693
# Activation function is LeakyReLU(negative_slope=0.01)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                 [128, 784]               0
#             Linear-2                 [128, 128]         100,480
#          LeakyReLU-3                 [128, 128]               0
#             Linear-4                 [128, 128]          16,512
#          LeakyReLU-5                 [128, 128]               0
#             Linear-6                  [128, 10]           1,290
# ================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.38
# Forward/backward pass size (MB): 1.28
# Params size (MB): 0.45
# Estimated Total Size (MB): 2.11
# ----------------------------------------------------------------
# Epoch: 1
# Loader: train. Accuracy: 0.8694
# Loader: valid. Accuracy: 0.9262
# Epoch: 2
# Loader: train. Accuracy: 0.9350833333333334
# Loader: valid. Accuracy: 0.9505
# Epoch: 3
# Loader: train. Accuracy: 0.9525166666666667
# Loader: valid. Accuracy: 0.9546
# Epoch: 4
# Loader: train. Accuracy: 0.963
# Loader: valid. Accuracy: 0.9609
# Epoch: 5
# Loader: train. Accuracy: 0.9697166666666667
# Loader: valid. Accuracy: 0.9682
# Epoch: 6
# Loader: train. Accuracy: 0.9747333333333333
# Loader: valid. Accuracy: 0.9685
# Epoch: 7
# Loader: train. Accuracy: 0.97895
# Loader: valid. Accuracy: 0.9709
# Epoch: 8
# Loader: train. Accuracy: 0.9810333333333333
# Loader: valid. Accuracy: 0.9718
# Epoch: 9
# Loader: train. Accuracy: 0.9824666666666667
# Loader: valid. Accuracy: 0.9719
# Epoch: 10
# Loader: train. Accuracy: 0.9841833333333333
# Loader: valid. Accuracy: 0.9731

# %% [markdown]
# ### Accuracy
# Построим график accuracy/epoch для каждой функции активации.

# %%
sns.set(style="darkgrid", font_scale=1.4)

plt.figure(figsize=(16, 10))
plt.title("Valid accuracy")
plt.plot(range(max_epochs), plain_accuracy, label="No activation", linewidth=2)
plt.plot(range(max_epochs), relu_accuracy, label="ReLU activation", linewidth=2)
plt.plot(range(max_epochs), leaky_relu_accuracy, label="LeakyReLU activation", linewidth=2)
plt.plot(range(max_epochs), elu_accuracy, label="ELU activation", linewidth=2)
plt.legend()
plt.xlabel("Epoch")
plt.show()

# %%
plt.figure(figsize=(16, 10))
plt.title("Valid accuracy")
plt.plot(range(max_epochs), relu_accuracy, label="ReLU activation", linewidth=2)
plt.plot(range(max_epochs), leaky_relu_accuracy, label="LeakyReLU activation", linewidth=2)
plt.plot(range(max_epochs), elu_accuracy, label="ELU activation", linewidth=2)
plt.legend()
plt.xlabel("Epoch")
plt.show()

# %% [markdown]
# **Вопрос 4.** Какая из активаций показала наивысший `accuracy` к концу обучения?
#
# **Ответ:** LeakyReLU

# %% [markdown]
# ## Часть 2.2 Сверточные нейронные сети

# %% [markdown]
# ### Ядра
# Сначала немного поработам с самим понятием ядра свёртки.

# %%
# !wget https://img.the-village.kz/the-village.com.kz/post-cover/5x5-I6oiwjmq79dMCZMEbA-default.jpg -O sample_photo.jpg
# Out:
# --2022-11-05 15:32:49--  https://img.the-village.kz/the-village.com.kz/post-cover/5x5-I6oiwjmq79dMCZMEbA-default.jpg
# Resolving img.the-village.kz (img.the-village.kz)... 144.76.208.75
# Connecting to img.the-village.kz (img.the-village.kz)|144.76.208.75|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://img.the-village-kz.com/the-village.com.kz/post-cover/5x5-I6oiwjmq79dMCZMEbA-default.jpg [following]
# --2022-11-05 15:32:49--  https://img.the-village-kz.com/the-village.com.kz/post-cover/5x5-I6oiwjmq79dMCZMEbA-default.jpg
# Resolving img.the-village-kz.com (img.the-village-kz.com)... 144.76.208.75
# Connecting to img.the-village-kz.com (img.the-village-kz.com)|144.76.208.75|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49337 (48K) [image/jpeg]
# Saving to: ‘sample_photo.jpg’
#
# sample_photo.jpg    100%[===================>]  48.18K  --.-KB/s    in 0.09s
#
# 2022-11-05 15:32:50 (526 KB/s) - ‘sample_photo.jpg’ saved [49337/49337]

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.9 MB)
#      |████████████████████████████████| 60.9 MB 10.4 MB/s eta 0:00:01   |███                             | 5.5 MB 1.7 MB/s eta 0:00:33
# Requirement already satisfied: numpy>=1.17.3 in /home/ilyakudryavtsev/anaconda3/lib/python3.9/site-packages (from opencv-python) (1.21.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.6.0.66

# %%
import cv2
sns.set(style="white")
img = cv2.imread("sample_photo.jpg")
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12, 8))
plt.imshow(RGB_img)
plt.show()

# %% [markdown]
# Попробуйте посмотреть как различные свертки влияют на фото. Например, попробуйте
#
# A)
# ```
# [0, 0, 0],
# [0, 1, 0],
# [0, 0, 0]
# ```
# Б)
# ```
# [0, 1, 0],
# [0, -2, 0],
# [0, 1, 0]
# ```
# В)
# ```
# [0, 0, 0],
# [1, -2, 1],
# [0, 0, 0]
# ```
# Г)
# ```
# [0, 1, 0],
# [1, -4, 1],
# [0, 1, 0]
# ```
# Д)
# ```
# [0, -1, 0],
# [-1, 5, -1],
# [0, -1, 0]
# ```
# Е)
# ```
# [0.0625, 0.125, 0.0625],
# [0.125, 0.25, 0.125],
# [0.0625, 0.125, 0.0625]
# ```
#
# Не стесняйтесь пробовать свои варианты!

# %%
img_t = torch.from_numpy(RGB_img).type(torch.float32).unsqueeze(0)
kernel = torch.tensor([
    [0.0625, 0.125, 0.0625],
    [0.125, 0.25, 0.125],
    [0.0625, 0.125, 0.0625]
]).reshape(1, 1, 3, 3).type(torch.float32)

kernel = kernel.repeat(3, 3, 1, 1)
img_t = img_t.permute(0, 3, 1, 2)  # [BS, H, W, C] -> [BS, C, H, W]
img_t = nn.ReflectionPad2d(1)(img_t)  # Pad Image for same output size

result = F.conv2d(img_t, kernel)[0]  #

# %%
plt.figure(figsize=(12, 8))
result_np = result.permute(1, 2, 0).numpy() / 256 / 3

plt.imshow(result_np)
plt.show()

# %% [markdown]
# **Вопрос 5.** Как можно описать действия ядер, приведенных выше? Сопоставьте для каждой буквы число.
#
# 1) Размытие
#
# 2) Увеличение резкости
#
# 3) Тождественное преобразование
#
# 4) Выделение вертикальных границ
#
# 5) Выделение горизонтальных границ
#
# 6) Выделение границ
#
# **Ответ:**
# А - 3
# Б - 5
# В - 4
# Г - 6
# Д - 2
# Е - 1

# %% [markdown]
# ### Задание. Реализуйте LeNet
#
# Если мы сделаем параметры сверток обучаемыми, то можем добиться хороших результатов для задач компьютерного зрения. Реализуйте архитектуру LeNet, предложенную еще в 1998 году!
# На этот раз используйте модульную структуру (без помощи класса Sequential).
#
# Наша нейронная сеть будет состоять из
# * Свёртки 3x3 (1 карта на входе, 6 на выходе) с активацией ReLU;
# * MaxPooling-а 2x2;
# * Свёртки 3x3 (6 карт на входе, 16 на выходе) с активацией ReLU;
# * MaxPooling-а 2x2;
# * Уплощения (nn.Flatten);
# * Полносвязного слоя со 120 нейронами и активацией ReLU;
# * Полносвязного слоя с 84 нейронами и активацией ReLU;
# * Выходного слоя из 10 нейронов.

# %%
class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        # 1 input image channel, 6 output channels, 3x3 square conv kernel
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = 6, kernel_size = 3)
        # MaxPooling 2x2
        self.pool1 = nn.MaxPool2d(kernel_size = 2)
        # 6 input channels, 16 output channels, 3x3 square conv kernel 
        self.conv2 = nn.Conv2d(in_channels = 6, out_channels = 16, kernel_size = 3)
        # MaxPooling 2x2
        self.pool2 = nn.MaxPool2d(kernel_size = 2)
        # Dense layer 1, 400 neurons in, 84 out
        self.fc1 = nn.Linear(400, 120)
        # Dense layer 2, 120 neurons in, 84 out
        self.fc2 = nn.Linear(120, 84)
        # Dense out layer, 84 neurons in, 10 out
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool1(F.relu(self.conv1(x)))
        x = self.pool2(F.relu(self.conv2(x)))
        m = nn.Flatten()
        x = m(x)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
    
        return x

# %%
model = LeNet()

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

loaders = {"train": train_dataloader, "valid": valid_dataloader}

# %% [markdown]
# ### Задание. Обучите CNN
# Используйте код обучения, который вы написали для полносвязной нейронной сети.

# %%
history = []
max_epochs = 10
accuracy = {"train": [], "valid": []}
for epoch in range(max_epochs):
    for k, dataloader in loaders.items():
        epoch_correct = 0
        epoch_all = 0
        for x_batch, y_batch in dataloader:
            if k == "train":
                model.train()
                optimizer.zero_grad()
                outp = model(x_batch)
                loss = criterion(outp, y_batch)
                history.append(loss.item())               
                loss.backward()
                optimizer.step()
            else:
                model.eval()
                with torch.no_grad():
                    outp = model(x_batch)
            preds = outp.argmax(-1)
            correct = (preds == y_batch).numpy().sum()
            all =  preds.shape[0]
            epoch_correct += correct.item()
            epoch_all += all
        if k == "train":
            print(f"Epoch: {epoch+1}")
        print(f"Loader: {k}. Accuracy: {epoch_correct/epoch_all}")
        accuracy[k].append(epoch_correct/epoch_all)
# Out:
# Epoch: 1
# Loader: train. Accuracy: 0.8764166666666666
# Loader: valid. Accuracy: 0.9616
# Epoch: 2
# Loader: train. Accuracy: 0.96405
# Loader: valid. Accuracy: 0.9727
# Epoch: 3
# Loader: train. Accuracy: 0.97585
# Loader: valid. Accuracy: 0.9759
# Epoch: 4
# Loader: train. Accuracy: 0.9820833333333333
# Loader: valid. Accuracy: 0.98
# Epoch: 5
# Loader: train. Accuracy: 0.9857666666666667
# Loader: valid. Accuracy: 0.9818
# Epoch: 6
# Loader: train. Accuracy: 0.9886166666666667
# Loader: valid. Accuracy: 0.9831
# Epoch: 7
# Loader: train. Accuracy: 0.9901666666666666
# Loader: valid. Accuracy: 0.9842
# Epoch: 8
# Loader: train. Accuracy: 0.9921833333333333
# Loader: valid. Accuracy: 0.9862
# Epoch: 9
# Loader: train. Accuracy: 0.9933833333333333
# Loader: valid. Accuracy: 0.9865
# Epoch: 10
# Loader: train. Accuracy: 0.9940166666666667
# Loader: valid. Accuracy: 0.9855

# %%
lenet_accuracy = accuracy["valid"]

# %% [markdown]
# Сравним с предыдущем пунктом

# %%
plt.figure(figsize=(16, 10))
plt.title("Valid accuracy")
plt.plot(range(max_epochs), relu_accuracy, label="ReLU activation", linewidth=2)
plt.plot(range(max_epochs), leaky_relu_accuracy, label="LeakyReLU activation", linewidth=2)
plt.plot(range(max_epochs), elu_accuracy, label="ELU activation", linewidth=2)
plt.plot(range(max_epochs), lenet_accuracy, label="LeNet", linewidth=2)
plt.legend()
plt.xlabel("Epoch")
plt.show()

# %% [markdown]
# **Вопрос 6**
# Какое `accuracy` получается после обучения с точностью до двух знаков после запятой?
#
# **Ответ:** 0.99
